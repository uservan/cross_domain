# %%
import pandas as pd

project_root = '/home/user/ondemand/program/verl'
path = os.path.join(project_root, "data/test_data/MATH-500.parquet")
df = pd.read_parquet(path)
# Out:
# 运行具有“verl (Python 3.10.0)”的单元格需要ipykernel包。
#
# 使用所需的包 <a href='command:jupyter.createPythonEnvAndSelectController'>创建 Python 环境</a>。

# %%
print(df.head())
print(df.columns)
